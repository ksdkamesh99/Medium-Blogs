# %%
cd /content/drive/My Drive/medium blogs/Image Color Seperation
# Out:
# /content/drive/My Drive/medium blogs/Image Color Seperation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from sklearn.cluster import KMeans

# %%
img=cv2.imread('image color2.jpg')

# %%
plt.imshow(img)

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img=img.reshape((img.shape[1]*img.shape[0],3))

# %%
md=[]

# %%
for i in range(1,21):
  kmeans=KMeans(n_clusters=i)
  kmeans.fit(img)
  o=kmeans.inertia_
  print(o)
  md.append(o)
# Out:
# 13107924711.978294
# 8433820366.758524
# 4507406394.104001
# 1906016765.3226116
# 1479036935.644275
# 1167644004.3794537
# 924556364.7463465
# 677398333.8710563
# 529621680.23856145
# 424009662.682969
# 359435146.0253957
# 297634711.33955854
# 252723281.89632946
# 220941246.79365787
# 193110661.4033114
# 172814060.41467503
# 155705229.97394535
# 142992728.61409003
# 131053276.08425024
# 118995898.8872379

# %%
md
# Out:
# [13107924711.978294,
#  8433820366.758524,
#  4507406394.104001,
#  1906016765.3226116,
#  1479036935.644275,
#  1167644004.3794537,
#  924556364.7463465,
#  677398333.8710563,
#  529621680.23856145,
#  424009662.682969,
#  359435146.0253957,
#  297634711.33955854,
#  252723281.89632946,
#  220941246.79365787,
#  193110661.4033114,
#  172814060.41467503,
#  155705229.97394535,
#  142992728.61409003,
#  131053276.08425024,
#  118995898.8872379]

# %%
len(md)
# Out:
# 20

# %%
plt.plot(list(np.arange(1,21)),md)
plt.show()

# %%
kmeans=KMeans(n_clusters=4)

# %%
s=kmeans.fit(img)

# %%
s
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels=kmeans.labels_

# %%
labels
# Out:
# array([2, 2, 2, ..., 2, 2, 2], dtype=int32)

# %%
centroid=kmeans.cluster_centers_

# %%
centroid
# Out:
# array([[  0.72872218, 155.47600455,   1.31370551],
#        [  3.32006311,   3.51864413, 160.61510694],
#        [  6.4469986 ,   8.99078351,  11.18966592],
#        [162.38139208,   0.62088701,   0.99487754]])

# %%
labels=list(labels)

# %%
percent=[]
for i in range(len(centroid)):
  j=labels.count(i)
  j=j/(len(labels))
  percent.append(j)

# %%
percent
# Out:
# [0.2098675925925926, 0.20776666666666666, 0.45601574074074075, 0.12635]

# %%
plt.pie(percent,colors=np.array(centroid/255),labels=np.arange(len(centroid)))
plt.show()
