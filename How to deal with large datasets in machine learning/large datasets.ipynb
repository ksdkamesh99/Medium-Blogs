# %%
cd /content/drive/My Drive/medium blogs/How to deal with Large Datasets in Machine Learning
# Out:
# /content/drive/My Drive/medium blogs/How to deal with Large Datasets in Machine Learning

# %%
# !unzip periods_test.csv.zip
# Out:
# Archive:  periods_test.csv.zip
# replace periods_test.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# %%time
import numpy as np
import pandas as pd
# Out:
# CPU times: user 15 µs, sys: 0 ns, total: 15 µs
# Wall time: 17.4 µs

# %%
# %%time
rows=1000000
columns=400
dataset=pd.DataFrame(np.random.randint(0,10,(rows,columns)),columns=['col'+str(i) for i in range(1,columns+1)])
# Out:
# CPU times: user 6.7 s, sys: 3.49 s, total: 10.2 s
# Wall time: 10.2 s

# %%
# %%time
print(dataset)
# Out:
#         col1  col2  col3  col4  col5  ...  col396  col397  col398  col399  col400
# 0          1     8     1     6     4  ...       8       7       2       9       1
# 1          3     3     3     0     7  ...       4       6       8       0       0
# 2          6     2     3     0     3  ...       7       8       2       3       8
# 3          3     3     8     3     2  ...       8       3       5       7       7
# 4          0     0     9     5     5  ...       7       3       6       0       8
# ...      ...   ...   ...   ...   ...  ...     ...     ...     ...     ...     ...
# 999995     7     9     9     1     4  ...       5       2       8       6       2
# 999996     3     2     2     8     7  ...       3       2       1       5       5
# 999997     8     3     0     0     6  ...       2       1       6       9       8
# 999998     1     9     6     0     6  ...       9       7       2       4       1
# ...

# %%
# %%time
dataset.to_csv('dataset.csv',index=False)
# Out:
# CPU times: user 47 s, sys: 2.02 s, total: 49 s
# Wall time: 54.7 s

# %%
# %%time
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Columns: 400 entries, col1 to col400
# dtypes: int64(400)
# memory usage: 3.0 GB
# CPU times: user 25.3 ms, sys: 0 ns, total: 25.3 ms
# Wall time: 26.3 ms

# %%
# %%time
dataset.memory_usage(deep=True).sum()*0.000001
# Out:
# CPU times: user 7.33 ms, sys: 0 ns, total: 7.33 ms
# Wall time: 7.24 ms
# 3200.0001279999997

# %%
# %%time
dataset.describe()
# Out:
# CPU times: user 43.3 s, sys: 3.3 s, total: 46.6 s
# Wall time: 46.7 s
#                  col1            col2  ...          col399          col400
# count  1000000.000000  1000000.000000  ...  1000000.000000  1000000.000000
# mean         4.502286        4.494709  ...        4.499940        4.500749
# std          2.874106        2.871369  ...        2.874389        2.874835
# min          0.000000        0.000000  ...        0.000000        0.000000
# 25%          2.000000        2.000000  ...        2.000000        2.000000
# 50%          5.000000        4.000000  ...        5.000000        5.000000
# 75%          7.000000        7.000000  ...        7.000000        7.000000
# max          9.000000        9.000000  ...        9.000000        9.000000
#
# [8 rows x 400 columns]

# %%
# %%time
data_chunk=pd.read_csv('dataset.csv',chunksize=100000)
data_chunk
# Out:
# CPU times: user 529 µs, sys: 6.23 ms, total: 6.76 ms
# Wall time: 11.9 ms

# %%
# %%time
chunk_data=[chunk for chunk in data_chunk]

dataset=pd.concat(chunk_data)

# %%
# %%time
dataset_original=pd.read_csv('dataset.csv')

# %%
# %%time
dataset.mean()
# Out:
# CPU times: user 671 ms, sys: 0 ns, total: 671 ms
# Wall time: 674 ms
# col1      4.500753
# col2      4.505240
# col3      4.497034
# col4      4.503972
# col5      4.495866
#             ...
# col396    4.501272
# col397    4.501198
# col398    4.501252
# col399    4.500384
# col400    4.498414
# Length: 400, dtype: float64

# %%
# %%time
dataset_original.mean()
# Out:
# CPU times: user 332 ms, sys: 0 ns, total: 332 ms
# Wall time: 337 ms
# col1      4.503119
# col2      4.498086
# col3      4.501065
# col4      4.502681
# col5      4.494823
#             ...
# col196    4.504348
# col197    4.500368
# col198    4.498853
# col199    4.501182
# col200    4.498225
# Length: 200, dtype: float64

# %%
dataset.dtypes
# Out:
# col1      int64
# col2      int64
# col3      int64
# col4      int64
# col5      int64
#           ...
# col396    int64
# col397    int64
# col398    int64
# col399    int64
# col400    int64
# Length: 400, dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Columns: 400 entries, col1 to col400
# dtypes: int64(400)
# memory usage: 3.0 GB

# %%
dataset.memory_usage(deep=True).sum()*0.000001
# Out:
# 3200.0001279999997

# %%
dataset=dataset.astype('int32')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Columns: 400 entries, col1 to col400
# dtypes: int32(400)
# memory usage: 1.5 GB

# %%
# %%time
dataset.mean()
# Out:
# CPU times: user 636 ms, sys: 762 µs, total: 637 ms
# Wall time: 641 ms
# col1      4.500753
# col2      4.505240
# col3      4.497034
# col4      4.503972
# col5      4.495866
#             ...
# col396    4.501272
# col397    4.501198
# col398    4.501252
# col399    4.500384
# col400    4.498414
# Length: 400, dtype: float64
